# %% [markdown]
# # 1. Views, Stored Procedure, and Transaction

# %% [markdown]
# - **Views** are a dynamic mechanism for presenting data from one or more tables.
#
# - A **Transaction** represents a complete unit of work, which can be one or more SQL statements.
#
#     - An **ACID transaction** is one where all the SQL statements must complete successfully, or none at all.
#
# - A **Stored Procedure** is a set of SQL statements that are stored and executed on the database server, allowing you to send one statement to execute all instead of sending multiple statements to achieve the same.
#     - You can write stored procedures in many different languages like SQL PL, PL/SQL, Java, and C.

# %% [markdown]
# # 2. Joins

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Cross-Join
# ![image.png](attachment:image.png)

# %% [markdown]
# ### NOTES: xx Join on xxx Where xxx vs. xx Join on xxx AND xxx

# %% [markdown]
# Example: See Lab 4 Problem 4 vs. Problem 5.
#
# Explaination: https://stackoverflow.com/questions/12400567/difference-between-on-and-and-on-where-in-sql-left-join
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Notes:
# - To combine data from three or more different tables, you simply add new joins to the SQL statement
# ```SQL
#
# xx join table on xxx
#
# xx join table2 on xxx
#
# ```
#
# - The most common type of join is the inner join, which matches the results from two tables and returns only the rows that match.
#
# - You can use a self-join (see Lab 4 Syntax section) to compare rows within the same table.
