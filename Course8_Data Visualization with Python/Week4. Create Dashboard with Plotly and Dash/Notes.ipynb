# %% [markdown]
# Summary:
# - This chapter focus on some other python libraries that have the functionality to create Dashboards in addition to plotting regular chart (compared to Matplotlib from previous chapters).

# %% [markdown]
# # 0. Introduction to Dashboards

# %% [markdown]
# Python Dashboarding Tools (source: https://pyviz.org/dashboarding/)
# - Dash (From Plotly)
# - Panel (From Anaconda)
# - Voila (from QuantStack)
# - Streamlit

# %% [markdown]
# # 1. Plotly

# %% [markdown]
# https://www.coursera.org/learn/python-for-data-visualization/supplement/HWNMI/additional-resources-for-plotly

# %% [markdown]
# 1. Plotly Basics - Using Plotly to plot regular charts (See Lab 1)

# %% [markdown]
# # 2. Dash

# %% [markdown]
# ## 2.1. Dash Basics - Create a Dashboard using Dash

# %% [markdown]
# https://www.coursera.org/learn/python-for-data-visualization/supplement/RpKoy/additional-resources-for-dash

# %% [markdown]
# 1. Dash is from Plotly
# 2. Dash is an Open Source User Interface Pytnon Library to build GUI (Dashboards), that can be rendered in Web Browser, and deployed to Servers.
# 3. Dash is cross-platform and mobile ready

# %% [markdown]
# Two Components:
# 1. Core components:
#     ```python
#     import dash_core_components as dcc
#     ```
# 2. HTML components:
#    ```python
#     import dash_html_components as html
#     ```

# %% [markdown]
# Dash Basics - HTML and Core Components (see Lab 2)

# %% [markdown]
# ## 2.2. Make Dashboard Interactive

# %% [markdown]
# https://www.coursera.org/learn/python-for-data-visualization/supplement/pW4w7/additional-resources-for-interactive-dashboards

# %% [markdown]
# a. Single Input/Output in a Dashboard: (See Lab 3 - "Add User Input and Callbacks")
# - Callback function is a python function that are automatically called by Dash whenever an input component's property changes (i.e. to achieve real-time calculation on user input)
# - Callback is composed of:
#     1. Callback decorator: @app.callback()
#     2. Callback function: def xxx:
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# b. Single Input/Multiple Outputs in a Dashboard: (See Lab 4 - "Flight Delay Time Statistics Dashboard")
