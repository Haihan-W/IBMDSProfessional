# %% [markdown]
# # 1. Python Libraries - 3 Types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Import / Export Datasets w/ Diff Data Format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > Note: **hdf** format is "Hierarchical Data Format"

# %% [markdown]
# # 3. Datatype in Panda vs. in native Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Statistical Summary in Panda Dataframe

# %% [markdown]
# - df.describe() : Quick Stats Summary --> Only for column with numbers
# - df.describe(include='all') : Full Stats Summary --> For all columns

# %% [markdown]
# # 5. Basic Info of Panda Dataframe

# %% [markdown]
# - df.info(): Print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
