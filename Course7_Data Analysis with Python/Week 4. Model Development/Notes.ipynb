# %% [markdown]
# # 1. Linear Regression and Multiple Linear Regression

# %% [markdown]
# > code:
#
#     > from sklearn.linear_model import LinearRegression
#     > lm=LinearRegression()
#
# - 1. Simple Linear Regression (1 x, 1 y)
#
# ![image.png](attachment:image.png)
#
#
# - 2. Multiple Linear Regression (multi x, 1 y)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2. Model Evaluation using Visualization

# %% [markdown]
# ### 2.1. Regression Plot

# %% [markdown]
# ![image.png](attachment:image.png)
# > the code above provide a simple linear regression and plot it as below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.2. Residual Plot

# %% [markdown]
# ![image.png](attachment:image.png)
# --> **note: this residual plot method above is only for simple linear regression's residual plot because it auto calculate the residual based on simple linear regression of y and x**
# > the code above predict y (yhat) using simple linear regression, and calculate diff between actual y and predicted y, and plot as below
#
# > EXPECTED Mean is 0 for residual plot
#
# > If the residual plot is not evenly distributed across the x, like below, the it means the simple linear regression model is not fit for the data
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2.3. Distribution Plot

# %% [markdown]
# - For continuous value, plot the density (frequency) distribution from min to max value
# - For discrete value, plot the count distribution from min to max value
#
#
# - For example, for car price, it is continuous value, the x-axis of the plot is the price itself, from min to max; the y-axis is the density distribution of the price, the y-axis value is proportional to how many cars falls under that price in x-axis.
#
#
# - And to evaluate actual car price vs. predicted car price, we can plot distribution of both variables in one plot using the code below:
#     - The more overlap between these two layers of plot, the most accurate the model is for car price prediction.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3. Ploynomial Regression and Pipelines

# %% [markdown]
# ### 3.1. Simple Polynomial Regression (1 x, 1 y)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > code:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.2. Multi-variate (multi-dim) Polynomial Regression (multi x, 1 y) (note: it can also be used for (1 x, 1y))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > code:
# - Step 1: ploynomial transform each variable to a new variable (e.g. X1X2 -> Z1; X1^2 -> Z2; X2^2 -> Z3; ...) **(the picture below only showed step 1, since step 2 is the same as Multi-linear regression code)**
# - Step 2: using normal multiple linear regression to fit the model as: Yhat=b0+b1X1+b2X2+b3Z1+b4Z2+b5Z3+... **(this step was not shown here, but shown in the lab section 3.2 under "Perform Multi-variate Ploynomial Regression step by step")**
# ![image.png](attachment:image.png)

# %% [markdown]
# > Example for step 1:
#     ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.3. Pipeline

# %% [markdown]
# - To simplify multiple steps to one step,
# - For example: for multi-polynomial regression, we may want to: 1. normalize the input variable; 2. polynomial transform input variable; 3. fit the regression
# - we can use model pipeline from sklearn to build the 3 steps into one pipeline, and use it everytime to train the model, to simplify the process:
# > ***!!!NOTE: Pipeline will automatically polytransform input X, don't need to do this step as in section above: pr.fit_transform(X)***  [This has been verified in Lab section 3.2 under "Perform Multi-variate Ploynomial Regression using Pipeline", the last step (compare coeff of two methods: using step by step vs. pipeline): coeff1==coeff2]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. In-Sample Model Evaluation using Numerical measures

# %% [markdown]
# two measures:
# - MSE (Mean Squared Error)
# - R-squared
#
#
# > Note: In-Sample Model Evaluation can only tell us how well model fits the training data (i.e. data to generate the model), cannot tell how well model performs in testing dataset (Out-of-sample evaluation).
#
# > Here we only covered In-Sample Model Evaluation, i.e. calculate R2 or MSE using training dataset rather than test dataset.
#
# > For the latter one, it will be covered in next Week's course: Model Evaluation.

# %% [markdown]
# ### 4.1. MSE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.2. R-square

# %% [markdown]
# > Def'n: percentage of the variation in the response variable y  that is explained by the variation in explanatory variable(s) x
#
# > code example for **simple/multi linear regression** - calculating R2
# ![image.png](attachment:image.png)
#
# > code example for **simple polynomial regression** - calculating R2
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 5. Prediction and Decision Making

# %% [markdown]
# > model.predict(x) -> predicted y #model is defined previously when fitting the model, e.g. lm

# %% [markdown]
# - how to check if the predicted values make sense?
#     - Visualization using Regression plot, Residual plot, Distribution plot
#     - Using Numerical Evaluation for the model: MSE, R-Square
